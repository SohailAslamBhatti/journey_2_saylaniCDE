# %%
# !pip install kaggle

# %%
import kaggle
# Out:
# Could not find kaggle.json. Make sure it's located in C:\Users\slubh\.kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import kaggle
#
# File ~\anaconda3\Lib\site-packages\kaggle\__init__.py:10
#       8 enable_oauth = os.environ.get("KAGGLE_ENABLE_OAUTH") in ("1", "true", "yes")
#       9 api = KaggleApi(enable_oauth=enable_oauth)
# ---> 10 api.authenticate()
#
# File ~\anaconda3\Lib\site-packages\kaggle\api\kaggle_api_extended.py:686, in KaggleApi.authenticate(self)
#     679 else:
#     680     print(
#     681         "Could not find {}. Make sure it's located in"
#     682         " {}. Or use the environment method. See setup"
#     683         " instructions at"
# ...
